# %%
from typing import Tuple
import warnings

import neptune.new as neptune
import neptune.new.integrations.optuna as optuna_utils

import optuna
import numpy as np
import pandas as pd

from optuna.pruners import MedianPruner
from optuna.samplers import RandomSampler
from optuna.study import Study
from optuna.trial import FrozenTrial
from optuna.integration.xgboost import XGBoostPruningCallback 
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

warnings.filterwarnings("ignore")

# %%
def load_dataset(path: str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    train = pd.read_csv(path + "train.csv")
    test = pd.read_csv(path + "test.csv")

    drops = ["조식메뉴", "중식메뉴", "석식메뉴"]

    train = train.drop(drops, axis=1)
    test = test.drop(drops, axis=1)

    train["월"] = pd.DatetimeIndex(train["일자"]).month
    test["월"] = pd.DatetimeIndex(test["일자"]).month

    train["일"] = pd.DatetimeIndex(train["일자"]).day
    test["일"] = pd.DatetimeIndex(test["일자"]).day

    weekday = {"월": 1, "화": 2, "수": 3, "목": 4, "금": 5}

    train["요일"] = train["요일"].map(weekday)
    test["요일"] = test["요일"].map(weekday)

    train["식사가능자수"] = train["본사정원수"] - train["본사휴가자수"] - train["현본사소속재택근무자수"]
    test["식사가능자수"] = test["본사정원수"] - test["본사휴가자수"] - test["현본사소속재택근무자수"]

    train["중식참여율"] = train["중식계"] / train["식사가능자수"]
    train["석식참여율"] = train["석식계"] / train["식사가능자수"]

    features = ["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]
    labels = ["중식계", "석식계", "중식참여율", "석식참여율"]

    train = train[features + labels]
    test = test[features]

    # 요일을 석식 rank에 맞춰 mapping한 요일(석식) 칼럼 만들기.

    weekday_rank4dinner = {
        1: 1,
        2: 2,
        3: 5,
        4: 3,
        5: 4,
    }

    train["요일(석식)"] = train["요일"].map(weekday_rank4dinner)
    test["요일(석식)"] = test["요일"].map(weekday_rank4dinner)

    return train, test

# %%
train, test = load_dataset("../input/predict-meals/")


X_lunch = train[["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]]
y_lunch = train["중식계"]
X_test = test[["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]]

x_train, x_valid, y_train, y_valid = train_test_split(
    X_lunch, y_lunch, test_size=0.15, random_state=42
)

# %%
def objective(trial: FrozenTrial) -> float:
    param = {
        "lambda": trial.suggest_loguniform("lambda", 1e-03, 1e-01),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 300),
        "random_state": 42,
        "learning_rate": 0.02,
        "n_estimators": 10000,
        "eval_metric": "mae",
    }

    pruning_callback = XGBoostPruningCallback(trial, "validation_1-mae")
    model = XGBRegressor(**param)

    model.fit(
        x_train,
        y_train,
        eval_set=[(x_train, y_train), (x_valid, y_valid)],
        early_stopping_rounds=100,
        callbacks=[pruning_callback], # pruning과정을 callback할 수 있음.
        verbose=False,
    )

    preds = model.predict(x_valid)

    mae = mean_absolute_error(y_valid, preds)

    return mae

# %%
# %%time
# run = neptune.init(
#     project="ds-wook/predict-meals",
#     # api_token="Anonymous",
# )

# # Create a NeptuneCallback for Optuna
# neptune_callback = optuna_utils.NeptuneCallback(
#     run,
#     plots_update_freq=1,  # create/log plots every 10 trials
#     log_plot_slice=False,  # do not create/log plot_slice
#     log_plot_contour=False,  # do not create/log plot_contour
# )

sampler = RandomSampler(seed=42)

study = optuna.create_study(
    study_name="optimization",
    direction="minimize",
    sampler=sampler,
    pruner=MedianPruner(n_warmup_steps=5), # 튜닝시 과적합 될 경우 가지치기
)

study.optimize(objective, n_trials=200)
# run.stop()
# Out:
# [I 2021-08-11 09:54:08,706] A new study created in memory with name: optimization
# [I 2021-08-11 09:54:10,311] Trial 0 finished with value: 83.16557893700363 and parameters: {'lambda': 0.005611516415334507, 'subsample': 0.9753571532049581, 'max_depth': 16, 'min_child_weight': 180}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:10,525] Trial 1 finished with value: 128.07020256927657 and parameters: {'lambda': 0.0020513382630874496, 'subsample': 0.5779972601681014, 'max_depth': 4, 'min_child_weight': 260}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:11,845] Trial 2 finished with value: 98.93614711023827 and parameters: {'lambda': 0.015930522616241012, 'subsample': 0.8540362888980227, 'max_depth': 3, 'min_child_weight': 291}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:12,878] Trial 3 finished with value: 75.97353805626295 and parameters: {'lambda': 0.04622589001020832, 'subsample': 0.6061695553391381, 'max_depth': 6, 'min_child_weight': 56}. Best is trial 3 with value: 75.97353805626295.
# [I 2021-08-11 09:54:13,772] Trial 4 finished with value: 78.69044014103505 and parameters: {'lambda': 0.0040596116104843075, 'subsample': 0.762378215816119, 'max_depth': 10, 'min_child_weight': 88}. Best is trial 3 with value: 75.97353805626295.
# [I 2021-08-11 09:54:13,780] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:13,800] Trial 6 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:13,809] Trial 7 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:13,896] Trial 8 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:13,973] Trial 9 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:14,067] Trial 10 pruned. Trial was pruned at iteration 81.
# [I 2021-08-11 09:54:14,076] Trial 11 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:14,167] Trial 12 pruned. Trial was pruned at iteration 81.
# [I 2021-08-11 09:54:14,240] Trial 13 pruned. Trial was pruned at iteration 69.
# [I 2021-08-11 09:54:14,251] Trial 14 pruned. Trial was pruned at iteration 6.
# [I 2021-08-11 09:54:14,280] Trial 15 pruned. Trial was pruned at iteration 11.
# [I 2021-08-11 09:54:14,365] Trial 16 pruned. Trial was pruned at iteration 74.
# [I 2021-08-11 09:54:14,374] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:14,454] Trial 18 pruned. Trial was pruned at iteration 66.
# [I 2021-08-11 09:54:14,465] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,038] Trial 20 finished with value: 73.78705643290314 and parameters: {'lambda': 0.05323617594751501, 'subsample': 0.811649063413779, 'max_depth': 8, 'min_child_weight': 20}. Best is trial 20 with value: 73.78705643290314.
# [I 2021-08-11 09:54:15,154] Trial 21 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:15,231] Trial 22 pruned. Trial was pruned at iteration 64.
# [I 2021-08-11 09:54:15,239] Trial 23 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,273] Trial 24 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,283] Trial 25 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,382] Trial 26 pruned. Trial was pruned at iteration 79.
# [I 2021-08-11 09:54:15,391] Trial 27 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,470] Trial 28 pruned. Trial was pruned at iteration 64.
# [I 2021-08-11 09:54:15,546] Trial 29 pruned. Trial was pruned at iteration 63.
# [I 2021-08-11 09:54:15,557] Trial 30 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,710] Trial 31 pruned. Trial was pruned at iteration 77.
# [I 2021-08-11 09:54:15,724] Trial 32 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,745] Trial 33 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,837] Trial 34 pruned. Trial was pruned at iteration 75.
# [I 2021-08-11 09:54:15,846] Trial 35 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,933] Trial 36 pruned. Trial was pruned at iteration 64.
# [I 2021-08-11 09:54:15,942] Trial 37 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:15,956] Trial 38 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:16,148] Trial 39 pruned. Trial was pruned at iteration 62.
# [I 2021-08-11 09:54:16,171] Trial 40 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:16,212] Trial 41 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,248] Trial 42 finished with value: 74.8457746136913 and parameters: {'lambda': 0.0012065637774378937, 'subsample': 0.795446471594121, 'max_depth': 15, 'min_child_weight': 5}. Best is trial 20 with value: 73.78705643290314.
# [I 2021-08-11 09:54:17,258] Trial 43 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,267] Trial 44 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,318] Trial 45 pruned. Trial was pruned at iteration 53.
# [I 2021-08-11 09:54:17,332] Trial 46 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,443] Trial 47 pruned. Trial was pruned at iteration 56.
# [I 2021-08-11 09:54:17,452] Trial 48 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,470] Trial 49 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,533] Trial 50 pruned. Trial was pruned at iteration 53.
# [I 2021-08-11 09:54:17,603] Trial 51 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:17,698] Trial 52 pruned. Trial was pruned at iteration 77.
# [I 2021-08-11 09:54:17,707] Trial 53 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,764] Trial 54 pruned. Trial was pruned at iteration 64.
# [I 2021-08-11 09:54:17,773] Trial 55 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,782] Trial 56 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,817] Trial 57 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,837] Trial 58 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,850] Trial 59 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,887] Trial 60 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,963] Trial 61 pruned. Trial was pruned at iteration 63.
# [I 2021-08-11 09:54:17,971] Trial 62 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,979] Trial 63 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:17,990] Trial 64 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,001] Trial 65 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,096] Trial 66 pruned. Trial was pruned at iteration 61.
# [I 2021-08-11 09:54:18,197] Trial 67 pruned. Trial was pruned at iteration 76.
# [I 2021-08-11 09:54:18,206] Trial 68 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,214] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,223] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,283] Trial 71 pruned. Trial was pruned at iteration 66.
# [I 2021-08-11 09:54:18,315] Trial 72 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,402] Trial 73 pruned. Trial was pruned at iteration 60.
# [I 2021-08-11 09:54:18,412] Trial 74 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,435] Trial 75 pruned. Trial was pruned at iteration 8.
# [I 2021-08-11 09:54:18,456] Trial 76 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,495] Trial 77 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,503] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,523] Trial 79 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,539] Trial 80 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,557] Trial 81 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,653] Trial 82 pruned. Trial was pruned at iteration 78.
# [I 2021-08-11 09:54:18,662] Trial 83 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,671] Trial 84 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,680] Trial 85 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,700] Trial 86 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:18,882] Trial 87 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:19,016] Trial 88 pruned. Trial was pruned at iteration 77.
# [I 2021-08-11 09:54:19,032] Trial 89 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,052] Trial 90 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,144] Trial 91 pruned. Trial was pruned at iteration 76.
# [I 2021-08-11 09:54:19,153] Trial 92 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,161] Trial 93 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,169] Trial 94 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,254] Trial 95 pruned. Trial was pruned at iteration 67.
# [I 2021-08-11 09:54:19,265] Trial 96 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,275] Trial 97 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:19,373] Trial 98 pruned. Trial was pruned at iteration 76.
# [I 2021-08-11 09:54:19,455] Trial 99 pruned. Trial was pruned at iteration 76.
# [I 2021-08-11 09:54:19,463] Trial 100 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,244] Trial 101 finished with value: 76.09881962728764 and parameters: {'lambda': 0.0043661555309361545, 'subsample': 0.9477616142481002, 'max_depth': 10, 'min_child_weight': 4}. Best is trial 20 with value: 73.78705643290314.
# [I 2021-08-11 09:54:20,281] Trial 102 pruned. Trial was pruned at iteration 44.
# [I 2021-08-11 09:54:20,290] Trial 103 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,384] Trial 104 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:20,406] Trial 105 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,536] Trial 106 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:20,554] Trial 107 pruned. Trial was pruned at iteration 7.
# [I 2021-08-11 09:54:20,568] Trial 108 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,603] Trial 109 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,619] Trial 110 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,657] Trial 111 pruned. Trial was pruned at iteration 15.
# [I 2021-08-11 09:54:20,673] Trial 112 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,683] Trial 113 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,716] Trial 114 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,732] Trial 115 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,820] Trial 116 pruned. Trial was pruned at iteration 67.
# [I 2021-08-11 09:54:20,828] Trial 117 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,921] Trial 118 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:20,932] Trial 119 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,940] Trial 120 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,948] Trial 121 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,956] Trial 122 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:20,988] Trial 123 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,055] Trial 124 pruned. Trial was pruned at iteration 44.
# [I 2021-08-11 09:54:21,132] Trial 125 pruned. Trial was pruned at iteration 69.
# [I 2021-08-11 09:54:21,185] Trial 126 pruned. Trial was pruned at iteration 45.
# [I 2021-08-11 09:54:21,195] Trial 127 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,231] Trial 128 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,249] Trial 129 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,344] Trial 130 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:21,353] Trial 131 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,439] Trial 132 pruned. Trial was pruned at iteration 71.
# [I 2021-08-11 09:54:21,522] Trial 133 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:21,532] Trial 134 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,539] Trial 135 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,553] Trial 136 pruned. Trial was pruned at iteration 12.
# [I 2021-08-11 09:54:21,561] Trial 137 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,582] Trial 138 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,592] Trial 139 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,652] Trial 140 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,669] Trial 141 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,791] Trial 142 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:21,852] Trial 143 pruned. Trial was pruned at iteration 70.
# [I 2021-08-11 09:54:21,861] Trial 144 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,883] Trial 145 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,893] Trial 146 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,961] Trial 147 pruned. Trial was pruned at iteration 6.
# [I 2021-08-11 09:54:21,973] Trial 148 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:21,992] Trial 149 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,003] Trial 150 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,033] Trial 151 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,053] Trial 152 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,125] Trial 153 pruned. Trial was pruned at iteration 46.
# [I 2021-08-11 09:54:22,220] Trial 154 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:22,228] Trial 155 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,323] Trial 156 pruned. Trial was pruned at iteration 67.
# [I 2021-08-11 09:54:22,367] Trial 157 pruned. Trial was pruned at iteration 46.
# [I 2021-08-11 09:54:22,376] Trial 158 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,398] Trial 159 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,415] Trial 160 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,426] Trial 161 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,460] Trial 162 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,482] Trial 163 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,501] Trial 164 pruned. Trial was pruned at iteration 8.
# [I 2021-08-11 09:54:22,522] Trial 165 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,551] Trial 166 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,637] Trial 167 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:54:22,752] Trial 168 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:22,831] Trial 169 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:22,891] Trial 170 pruned. Trial was pruned at iteration 64.
# [I 2021-08-11 09:54:22,909] Trial 171 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:22,930] Trial 172 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,010] Trial 173 pruned. Trial was pruned at iteration 62.
# [I 2021-08-11 09:54:23,019] Trial 174 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,028] Trial 175 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,036] Trial 176 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,057] Trial 177 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,147] Trial 178 pruned. Trial was pruned at iteration 75.
# [I 2021-08-11 09:54:23,164] Trial 179 pruned. Trial was pruned at iteration 15.
# [I 2021-08-11 09:54:23,256] Trial 180 pruned. Trial was pruned at iteration 76.
# [I 2021-08-11 09:54:23,266] Trial 181 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,337] Trial 182 pruned. Trial was pruned at iteration 55.
# [I 2021-08-11 09:54:23,419] Trial 183 pruned. Trial was pruned at iteration 74.
# [I 2021-08-11 09:54:23,431] Trial 184 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,439] Trial 185 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,448] Trial 186 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,534] Trial 187 pruned. Trial was pruned at iteration 70.
# [I 2021-08-11 09:54:23,619] Trial 188 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:23,670] Trial 189 pruned. Trial was pruned at iteration 8.
# [I 2021-08-11 09:54:23,820] Trial 190 pruned. Trial was pruned at iteration 74.
# [I 2021-08-11 09:54:23,905] Trial 191 pruned. Trial was pruned at iteration 73.
# [I 2021-08-11 09:54:23,913] Trial 192 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,922] Trial 193 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,960] Trial 194 pruned. Trial was pruned at iteration 14.
# [I 2021-08-11 09:54:23,980] Trial 195 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:23,995] Trial 196 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:24,004] Trial 197 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:24,103] Trial 198 pruned. Trial was pruned at iteration 70.
# [I 2021-08-11 09:54:24,184] Trial 199 pruned. Trial was pruned at iteration 73.
# CPU times: user 1min 49s, sys: 969 ms, total: 1min 50s
# Wall time: 15.5 s

# %%
print("Best trial:")
trial = study.best_trial
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print(f"    '{key}': {value},")
# Out:
# Best trial:
#   Value:  73.78705643290314
#   Params:
#     'lambda': 0.05323617594751501,
#     'subsample': 0.811649063413779,
#     'max_depth': 8,
#     'min_child_weight': 20,
