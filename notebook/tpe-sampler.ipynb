# %%
from typing import Tuple
import warnings

import neptune.new as neptune
import neptune.new.integrations.optuna as optuna_utils

import optuna
import numpy as np
import pandas as pd

from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from optuna.study import Study
from optuna.trial import FrozenTrial
from optuna.integration.xgboost import XGBoostPruningCallback 
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

warnings.filterwarnings("ignore")

# %%
def load_dataset(path: str) -> Tuple[pd.DataFrame, pd.DataFrame]:
    train = pd.read_csv(path + "train.csv")
    test = pd.read_csv(path + "test.csv")

    drops = ["조식메뉴", "중식메뉴", "석식메뉴"]

    train = train.drop(drops, axis=1)
    test = test.drop(drops, axis=1)

    train["월"] = pd.DatetimeIndex(train["일자"]).month
    test["월"] = pd.DatetimeIndex(test["일자"]).month

    train["일"] = pd.DatetimeIndex(train["일자"]).day
    test["일"] = pd.DatetimeIndex(test["일자"]).day

    weekday = {"월": 1, "화": 2, "수": 3, "목": 4, "금": 5}

    train["요일"] = train["요일"].map(weekday)
    test["요일"] = test["요일"].map(weekday)

    train["식사가능자수"] = train["본사정원수"] - train["본사휴가자수"] - train["현본사소속재택근무자수"]
    test["식사가능자수"] = test["본사정원수"] - test["본사휴가자수"] - test["현본사소속재택근무자수"]

    train["중식참여율"] = train["중식계"] / train["식사가능자수"]
    train["석식참여율"] = train["석식계"] / train["식사가능자수"]

    features = ["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]
    labels = ["중식계", "석식계", "중식참여율", "석식참여율"]

    train = train[features + labels]
    test = test[features]

    # 요일을 석식 rank에 맞춰 mapping한 요일(석식) 칼럼 만들기.

    weekday_rank4dinner = {
        1: 1,
        2: 2,
        3: 5,
        4: 3,
        5: 4,
    }

    train["요일(석식)"] = train["요일"].map(weekday_rank4dinner)
    test["요일(석식)"] = test["요일"].map(weekday_rank4dinner)

    return train, test

# %% [markdown]
# # 예시를 위해 점심 식수 인원만 예측 튜닝

# %%
train, test = load_dataset("../input/predict-meals/")


X_lunch = train[["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]]
y_lunch = train["중식계"]
X_test = test[["월", "일", "요일", "식사가능자수", "본사출장자수", "본사시간외근무명령서승인건수"]]

x_train, x_valid, y_train, y_valid = train_test_split(
    X_lunch, y_lunch, test_size=0.15, random_state=42
)

# %%
def objective(trial: FrozenTrial) -> float:
    param = {
        "lambda": trial.suggest_loguniform("lambda", 1e-03, 1e-01),
        "subsample": trial.suggest_float("subsample", 0.5, 1),
        "max_depth": trial.suggest_int("max_depth", 3, 20),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 300),
        "random_state": 42,
        "learning_rate": 0.02,
        "n_estimators": 10000,
        "eval_metric": "mae",
    }

    pruning_callback = XGBoostPruningCallback(trial, "validation_1-mae")
    model = XGBRegressor(**param)

    model.fit(
        x_train,
        y_train,
        eval_set=[(x_train, y_train), (x_valid, y_valid)],
        early_stopping_rounds=100,
        callbacks=[pruning_callback], # pruning과정을 callback할 수 있음.
        verbose=False,
    )

    preds = model.predict(x_valid)

    mae = mean_absolute_error(y_valid, preds)

    return mae

# %%
# %%time
# run = neptune.init(
#     project="ds-wook/predict-meals",
#     # api_token="Anonymous",
# )

# # Create a NeptuneCallback for Optuna
# neptune_callback = optuna_utils.NeptuneCallback(
#     run,
#     plots_update_freq=1,  # create/log plots every 10 trials
#     log_plot_slice=False,  # do not create/log plot_slice
#     log_plot_contour=False,  # do not create/log plot_contour
# )

sampler = TPESampler(seed=42)

study = optuna.create_study(
    study_name="optimization",
    direction="minimize",
    sampler=sampler,
    pruner=MedianPruner(n_warmup_steps=5), # 튜닝시 과적합 될 경우 가지치기
)

study.optimize(objective, n_trials=200)
# run.stop()
# Out:
# [I 2021-08-11 09:54:48,197] A new study created in memory with name: optimization
# [I 2021-08-11 09:54:49,453] Trial 0 finished with value: 83.16557893700363 and parameters: {'lambda': 0.005611516415334507, 'subsample': 0.9753571532049581, 'max_depth': 16, 'min_child_weight': 180}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:49,722] Trial 1 finished with value: 128.07020256927657 and parameters: {'lambda': 0.0020513382630874496, 'subsample': 0.5779972601681014, 'max_depth': 4, 'min_child_weight': 260}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:51,065] Trial 2 finished with value: 98.93614711023827 and parameters: {'lambda': 0.015930522616241012, 'subsample': 0.8540362888980227, 'max_depth': 3, 'min_child_weight': 291}. Best is trial 0 with value: 83.16557893700363.
# [I 2021-08-11 09:54:51,802] Trial 3 finished with value: 75.97353805626295 and parameters: {'lambda': 0.04622589001020832, 'subsample': 0.6061695553391381, 'max_depth': 6, 'min_child_weight': 56}. Best is trial 3 with value: 75.97353805626295.
# [I 2021-08-11 09:54:52,535] Trial 4 finished with value: 78.69044014103505 and parameters: {'lambda': 0.0040596116104843075, 'subsample': 0.762378215816119, 'max_depth': 10, 'min_child_weight': 88}. Best is trial 3 with value: 75.97353805626295.
# [I 2021-08-11 09:54:52,544] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:52,561] Trial 6 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:52,647] Trial 7 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:52,704] Trial 8 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:52,787] Trial 9 pruned. Trial was pruned at iteration 65.
# [I 2021-08-11 09:54:53,324] Trial 10 finished with value: 73.06928468145718 and parameters: {'lambda': 0.09036331363174513, 'subsample': 0.6684840248658571, 'max_depth': 7, 'min_child_weight': 4}. Best is trial 10 with value: 73.06928468145718.
# [I 2021-08-11 09:54:53,852] Trial 11 finished with value: 73.70748682180162 and parameters: {'lambda': 0.09497084962077733, 'subsample': 0.6706402814619924, 'max_depth': 7, 'min_child_weight': 6}. Best is trial 10 with value: 73.06928468145718.
# [I 2021-08-11 09:54:53,899] Trial 12 pruned. Trial was pruned at iteration 15.
# [I 2021-08-11 09:54:53,938] Trial 13 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:54,850] Trial 14 finished with value: 74.29486050263294 and parameters: {'lambda': 0.04299274004089067, 'subsample': 0.6628791070023721, 'max_depth': 11, 'min_child_weight': 3}. Best is trial 10 with value: 73.06928468145718.
# [I 2021-08-11 09:54:54,880] Trial 15 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:54,915] Trial 16 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:54,939] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,000] Trial 18 pruned. Trial was pruned at iteration 33.
# [I 2021-08-11 09:54:55,033] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,057] Trial 20 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,100] Trial 21 pruned. Trial was pruned at iteration 8.
# [I 2021-08-11 09:54:55,140] Trial 22 pruned. Trial was pruned at iteration 9.
# [I 2021-08-11 09:54:55,195] Trial 23 pruned. Trial was pruned at iteration 20.
# [I 2021-08-11 09:54:55,227] Trial 24 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,256] Trial 25 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,291] Trial 26 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,352] Trial 27 pruned. Trial was pruned at iteration 19.
# [I 2021-08-11 09:54:55,385] Trial 28 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,476] Trial 29 pruned. Trial was pruned at iteration 74.
# [I 2021-08-11 09:54:55,509] Trial 30 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,548] Trial 31 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,579] Trial 32 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,608] Trial 33 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,642] Trial 34 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,719] Trial 35 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,752] Trial 36 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,776] Trial 37 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,841] Trial 38 pruned. Trial was pruned at iteration 39.
# [I 2021-08-11 09:54:55,901] Trial 39 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:54:55,934] Trial 40 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,958] Trial 41 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:55,991] Trial 42 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,025] Trial 43 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,061] Trial 44 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,089] Trial 45 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,117] Trial 46 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,141] Trial 47 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,192] Trial 48 pruned. Trial was pruned at iteration 14.
# [I 2021-08-11 09:54:56,238] Trial 49 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,279] Trial 50 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,314] Trial 51 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,342] Trial 52 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,426] Trial 53 pruned. Trial was pruned at iteration 61.
# [I 2021-08-11 09:54:56,458] Trial 54 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:56,516] Trial 55 pruned. Trial was pruned at iteration 42.
# [I 2021-08-11 09:54:56,540] Trial 56 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,193] Trial 57 finished with value: 72.22710911871978 and parameters: {'lambda': 0.03418313169716836, 'subsample': 0.6146465660294592, 'max_depth': 17, 'min_child_weight': 11}. Best is trial 57 with value: 72.22710911871978.
# [I 2021-08-11 09:54:57,229] Trial 58 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,255] Trial 59 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,293] Trial 60 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,356] Trial 61 pruned. Trial was pruned at iteration 18.
# [I 2021-08-11 09:54:57,391] Trial 62 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,426] Trial 63 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,454] Trial 64 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:57,527] Trial 65 pruned. Trial was pruned at iteration 50.
# [I 2021-08-11 09:54:58,305] Trial 66 finished with value: 74.01446398318802 and parameters: {'lambda': 0.014038209887774489, 'subsample': 0.637794559021936, 'max_depth': 14, 'min_child_weight': 10}. Best is trial 57 with value: 72.22710911871978.
# [I 2021-08-11 09:54:58,347] Trial 67 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,063] Trial 68 finished with value: 73.58042646376468 and parameters: {'lambda': 0.029060334479694087, 'subsample': 0.6364071208908934, 'max_depth': 11, 'min_child_weight': 10}. Best is trial 57 with value: 72.22710911871978.
# [I 2021-08-11 09:54:59,102] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,137] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,171] Trial 71 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,205] Trial 72 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,237] Trial 73 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,271] Trial 74 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,307] Trial 75 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,340] Trial 76 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,519] Trial 77 pruned. Trial was pruned at iteration 97.
# [I 2021-08-11 09:54:59,550] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,591] Trial 79 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,623] Trial 80 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:54:59,707] Trial 81 pruned. Trial was pruned at iteration 48.
# [I 2021-08-11 09:54:59,740] Trial 82 pruned. Trial was pruned at iteration 9.
# [I 2021-08-11 09:55:00,017] Trial 83 pruned. Trial was pruned at iteration 158.
# [I 2021-08-11 09:55:00,063] Trial 84 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,129] Trial 85 pruned. Trial was pruned at iteration 48.
# [I 2021-08-11 09:55:00,160] Trial 86 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,192] Trial 87 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,228] Trial 88 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,259] Trial 89 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,287] Trial 90 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,360] Trial 91 pruned. Trial was pruned at iteration 46.
# [I 2021-08-11 09:55:00,399] Trial 92 pruned. Trial was pruned at iteration 15.
# [I 2021-08-11 09:55:00,425] Trial 93 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,461] Trial 94 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,492] Trial 95 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,524] Trial 96 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,557] Trial 97 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,589] Trial 98 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,617] Trial 99 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:00,708] Trial 100 pruned. Trial was pruned at iteration 43.
# [I 2021-08-11 09:55:00,822] Trial 101 pruned. Trial was pruned at iteration 40.
# [I 2021-08-11 09:55:00,889] Trial 102 pruned. Trial was pruned at iteration 38.
# [I 2021-08-11 09:55:00,945] Trial 103 pruned. Trial was pruned at iteration 39.
# [I 2021-08-11 09:55:00,978] Trial 104 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,033] Trial 105 pruned. Trial was pruned at iteration 34.
# [I 2021-08-11 09:55:01,063] Trial 106 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,134] Trial 107 pruned. Trial was pruned at iteration 46.
# [I 2021-08-11 09:55:01,164] Trial 108 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,228] Trial 109 pruned. Trial was pruned at iteration 41.
# [I 2021-08-11 09:55:01,259] Trial 110 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,292] Trial 111 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,328] Trial 112 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,363] Trial 113 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,392] Trial 114 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,427] Trial 115 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,461] Trial 116 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,495] Trial 117 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,525] Trial 118 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,552] Trial 119 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:01,608] Trial 120 pruned. Trial was pruned at iteration 28.
# [I 2021-08-11 09:55:01,642] Trial 121 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,003] Trial 122 pruned. Trial was pruned at iteration 143.
# [I 2021-08-11 09:55:02,708] Trial 123 finished with value: 73.51490303166005 and parameters: {'lambda': 0.003694020934574543, 'subsample': 0.6024686118974462, 'max_depth': 10, 'min_child_weight': 8}. Best is trial 57 with value: 72.22710911871978.
# [I 2021-08-11 09:55:02,740] Trial 124 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,769] Trial 125 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,847] Trial 126 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:55:02,880] Trial 127 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,906] Trial 128 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,945] Trial 129 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:02,991] Trial 130 pruned. Trial was pruned at iteration 9.
# [I 2021-08-11 09:55:03,028] Trial 131 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,055] Trial 132 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,333] Trial 133 pruned. Trial was pruned at iteration 131.
# [I 2021-08-11 09:55:03,366] Trial 134 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,392] Trial 135 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,428] Trial 136 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,462] Trial 137 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,497] Trial 138 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,524] Trial 139 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:03,599] Trial 140 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:55:03,887] Trial 141 pruned. Trial was pruned at iteration 163.
# [I 2021-08-11 09:55:04,186] Trial 142 pruned. Trial was pruned at iteration 164.
# [I 2021-08-11 09:55:04,243] Trial 143 pruned. Trial was pruned at iteration 19.
# [I 2021-08-11 09:55:04,279] Trial 144 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:04,727] Trial 145 pruned. Trial was pruned at iteration 164.
# [I 2021-08-11 09:55:04,765] Trial 146 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:04,792] Trial 147 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:04,840] Trial 148 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:04,876] Trial 149 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:04,905] Trial 150 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:05,259] Trial 151 pruned. Trial was pruned at iteration 180.
# [I 2021-08-11 09:55:05,605] Trial 152 pruned. Trial was pruned at iteration 191.
# [I 2021-08-11 09:55:05,635] Trial 153 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:05,743] Trial 154 pruned. Trial was pruned at iteration 33.
# [I 2021-08-11 09:55:06,367] Trial 155 finished with value: 74.04307665745857 and parameters: {'lambda': 0.0038150552406722702, 'subsample': 0.681882510781594, 'max_depth': 11, 'min_child_weight': 11}. Best is trial 57 with value: 72.22710911871978.
# [I 2021-08-11 09:55:06,401] Trial 156 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:06,466] Trial 157 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:06,516] Trial 158 pruned. Trial was pruned at iteration 15.
# [I 2021-08-11 09:55:06,545] Trial 159 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:06,572] Trial 160 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:06,802] Trial 161 pruned. Trial was pruned at iteration 123.
# [I 2021-08-11 09:55:06,834] Trial 162 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,199] Trial 163 pruned. Trial was pruned at iteration 130.
# [I 2021-08-11 09:55:07,225] Trial 164 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,488] Trial 165 pruned. Trial was pruned at iteration 155.
# [I 2021-08-11 09:55:07,553] Trial 166 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:55:07,595] Trial 167 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,626] Trial 168 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,651] Trial 169 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,689] Trial 170 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:07,990] Trial 171 pruned. Trial was pruned at iteration 171.
# [I 2021-08-11 09:55:08,323] Trial 172 pruned. Trial was pruned at iteration 123.
# [I 2021-08-11 09:55:08,427] Trial 173 pruned. Trial was pruned at iteration 47.
# [I 2021-08-11 09:55:08,466] Trial 174 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,505] Trial 175 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,535] Trial 176 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,567] Trial 177 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,603] Trial 178 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,634] Trial 179 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,667] Trial 180 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:08,932] Trial 181 pruned. Trial was pruned at iteration 125.
# [I 2021-08-11 09:55:09,177] Trial 182 pruned. Trial was pruned at iteration 116.
# [I 2021-08-11 09:55:09,497] Trial 183 pruned. Trial was pruned at iteration 130.
# [I 2021-08-11 09:55:09,531] Trial 184 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,571] Trial 185 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,607] Trial 186 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,637] Trial 187 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,696] Trial 188 pruned. Trial was pruned at iteration 38.
# [I 2021-08-11 09:55:09,745] Trial 189 pruned. Trial was pruned at iteration 14.
# [I 2021-08-11 09:55:09,779] Trial 190 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,808] Trial 191 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,849] Trial 192 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,888] Trial 193 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:09,933] Trial 194 pruned. Trial was pruned at iteration 8.
# [I 2021-08-11 09:55:09,966] Trial 195 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:10,000] Trial 196 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:10,039] Trial 197 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:10,074] Trial 198 pruned. Trial was pruned at iteration 5.
# [I 2021-08-11 09:55:10,108] Trial 199 pruned. Trial was pruned at iteration 5.
# CPU times: user 2min 34s, sys: 656 ms, total: 2min 35s
# Wall time: 21.9 s

# %%
print("Best trial:")
trial = study.best_trial
print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print(f"    '{key}': {value},")
# Out:
# Best trial:
#   Value:  72.22710911871978
#   Params:
#     'lambda': 0.03418313169716836,
#     'subsample': 0.6146465660294592,
#     'max_depth': 17,
#     'min_child_weight': 11,
